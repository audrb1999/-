# %% [markdown]
# <a href="https://colab.research.google.com/github/audrb1999/Python_image/blob/main/git_hub10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***11. 중급 Captcha Hacking ①***
#
# - 코랩에서 실행이 안되는 내용입니다.

# %%
# !git clone https://github.com/ndb796/SCTF2017-Writeups.git
# Out:
#      <input type="file" id="files-f882b5e5-507a-471b-b07c-9314eaba6d28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f882b5e5-507a-471b-b07c-9314eaba6d28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving digits.png to digits.png

# %%
import os
os.chdir('/content/SCTF2017-Writeups/ASM/src/')
# Out:
# (1000, 2000)
# (50, 100, 20, 20)
# (5000, 400)
# (5000, 1)

# %% [markdown]
# 1. ASM안에 static 폴더를 만들고 그 안에images 폴더 만들기
#
# 2. 문제 출제를 위한 플라스크 웹 소스코드 구동

# %% [markdown]
# 이 문제는 if session['correct'] > = 30 and \로 30개의 이미지만 맞추면 flag를 얻을 수 있게 난이도가 내려간 문제 > 컴퓨터 성능에 맞춰

# %% [markdown]
# - 플라스크 구동을 위한 플라스크 라이브러리 설치

# %%
# !pip install flask

# %%
# !python3 run.py

# %% [markdown]
# ##**코랩 환경에서는 실행이 안됨! 명령 프롬프트로 실행해야 됨!**
# - 아마 엑세스 권한이 있어야 실행되는듯!
#
# 제대로 됬다면 localhost:10000 검색시 이렇게 뜸
#
# start를 누르면 문제가 static/images 파일로 전송됨

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 많은 연산 문제들을 짧은 시간에 맞추기 힘드므로 해킹툴을 이용해야함!

# %% [markdown]
# 문제 동작
#
# - Start 버튼을 누르면 80초 타이머가 동작합니다.
#
# - Captcha와 같은 형태로 수식이 등장하며, 이를 반복적으로 풀어야 합니다.
#
# - 80초 안에 100개의 수식에 대하여 연속적으로 정답 처리를 받아야 합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 하지만 문제점이 있습니다.
#
# 1. 문제를 거듭하여 풀수록 수식의 길이가 길어집니다.
#
# 2. 이미지에서 각 문자는 색상으로 구분되어 있는데 이를 어떻게 정확히 분리할 수 있을까요?
